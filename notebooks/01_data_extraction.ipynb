# %% [markdown]
# # Data Extraction
# ---

# %% [markdown]
# ## Import Libraries

# %%
# import libraries
import pandas as pd 
import kagglehub # import data via Kaggle API
import os

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Download Dataset

# %%
# Download data from Kaggle to local machine
path = kagglehub.dataset_download("nih-chest-xrays/data")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Download data from Kaggle to local machine
# ----> 2 path = kagglehub.dataset_download("nih-chest-xrays/data")
#       3
#       4 print("Path to dataset files:", path)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/datasets.py:35, in dataset_download(handle, path, force_download)
#      33 h = parse_dataset_handle(handle)
#      34 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 35 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      36 return path
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      24 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/http_resolver.py:107, in DatasetHttpResolver._resolve(self, h, path, force_download)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/http_resolver.py:290, in _get_current_version(api_client, h)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/kagglehub/clients.py:133, in KaggleApiV1Client.get(self, path, resource_handle)
#     131 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587 send_kwargs = {
#     588     "timeout": timeout,
#     589     "allow_redirects": allow_redirects,
#     590 }
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/sessions.py:706, in Session.send(self, request, **kwargs)
#     703 start = preferred_clock()
#     705 # Send the request
# --> 706 r = adapter.send(request, **kwargs)
#     708 # Total elapsed time of the request (approximately)
#     709 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/adapters.py:617, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     614 except LocationValueError as e:
#     615     raise InvalidURL(e, request=request)
# --> 617 self.cert_verify(conn, request.url, verify, cert)
#     618 url = self.request_url(request, proxies)
#     619 self.add_headers(
#     620     request,
#     621     stream=stream,
#    (...)    625     proxies=proxies,
#     626 )
#
# File ~/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/requests/adapters.py:304, in HTTPAdapter.cert_verify(self, conn, url, verify, cert)
#     301     cert_loc = DEFAULT_CA_BUNDLE_PATH
#     303 if not cert_loc or not os.path.exists(cert_loc):
# --> 304     raise OSError(
#     305         f"Could not find a suitable TLS CA certificate bundle, "
#     306         f"invalid path: {cert_loc}"
#     307     )
#     309 conn.cert_reqs = "CERT_REQUIRED"
#     311 if not os.path.isdir(cert_loc):
#
# OSError: Could not find a suitable TLS CA certificate bundle, invalid path: /Users/williamnguyen/Documents/GitHub/Deep-Learning-Medical-Diagnosis-Predictor/venv/lib/python3.11/site-packages/certifi/cacert.pem

# %% [markdown]
# ## Extract Raw Data

# %%
# extract data entry file
data_entry_df = pd.read_csv(os.path.join(path,'Data_Entry_2017.csv'))
data_entry_df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_000.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           58              M            PA                 2682     2749
# 1           58              M            PA                 2894     2729
# 2           58              M            PA                 2500     2048
# 3           81              M            PA                 2500     2048
# 4           81              F            PA                 2582     2991
#
#    OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 0                        0.143  0.143          NaN
# 1                        0.143  0.143          NaN
# 2                        0.168  0.168          NaN
# 3                        0.171  0.171          NaN
# 4                        0.143  0.143          NaN

# %%
# extract bounding box coordinates 
bbox_list = pd.read_csv(os.path.join(path,'BBox_List_2017.csv'))
bbox_list.head()
# Out:
#         Image Index Finding Label     Bbox [x           y           w  \
# 0  00013118_008.png   Atelectasis  225.084746  547.019217   86.779661
# 1  00014716_007.png   Atelectasis  686.101695  131.543498  185.491525
# 2  00029817_009.png   Atelectasis  221.830508  317.053115  155.118644
# 3  00014687_001.png   Atelectasis  726.237288  494.951420  141.016949
# 4  00017877_001.png   Atelectasis  660.067797  569.780787  200.677966
#
#            h]  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0   79.186441         NaN         NaN         NaN
# 1  313.491525         NaN         NaN         NaN
# 2  216.949153         NaN         NaN         NaN
# 3   55.322034         NaN         NaN         NaN
# 4   78.101695         NaN         NaN         NaN

# %%
# extract test split list
test_list = pd.read_csv(os.path.join(path, 'test_list.txt'))
test_list.shape
# Out:
# (25595, 1)

# %%
# extract train split list
train_val_list = pd.read_csv(os.path.join(path, 'train_val_list.txt'))
train_val_list.shape
# Out:
# (86523, 1)

# %% [markdown]
# ## Save to Interim

# %%
# Save extracted data to the interim folder as .pkl file

data_entry_df.to_pickle('../data/interim/data_entry_df.pkl')
bbox_list.to_pickle('../data/interim/bbox_list.pkl')
test_list.to_pickle('../data/interim/test_list.pkl')
train_val_list.to_pickle('../data/interim/train_val_list.pkl')
